# %% [markdown]
# # Set Up

# %% [markdown]
# You need to have Windows 11 or newer to run the crawler.
#
# Please ensure Google Chrome driver is installed on your local drive. Please refer the [instructions](https://chromedriver.chromium.org/downloads) for more details.
#
# Current Releases
# If you are using Chrome version 97, please download ChromeDriver [97.0.4692.36](https://chromedriver.storage.googleapis.com/index.html?path=97.0.4692.36/)
#
# If you are using Chrome version 96, please download ChromeDriver [96.0.4664.45](https://chromedriver.storage.googleapis.com/index.html?path=96.0.4664.45/)
#
# If you are using Chrome version 95, please download ChromeDriver [95.0.4638.69](https://chromedriver.storage.googleapis.com/index.html?path=95.0.4638.69/)
#
# For older version of Chrome, please see below for the version of ChromeDriver that supports it.
#
# If you are using Chrome from Dev or Canary channel, please following instructions on the [ChromeDriver Canary](https://chromedriver.chromium.org/chromedriver-canary)page.
#
# For more information on selecting the right version of ChromeDriver, please see the [Version Selection](https://chromedriver.chromium.org/downloads/version-selection) page.

# %% [markdown]
# # Access to the ZeroCarbonFly

# %% [markdown]
# For the quickest introduction to ZeroCarbonFly, close the repository to your local computer. Navigate to the corresponding directory where the repo is saved, then navigate to the ZeroCarbonFly folder, then run the following command in your Windows Terminal.

# %% [markdown]
# ```pip install --upgrade streamlit
# streamlit run Website.py```

# %% [markdown]
# # Input Your Flight Information

# %% [markdown]
# Please put in the Airports Code, Date, Number of Passengers, Class in our website and it will get all the infroamtions of the flights on the specific day.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Get your Flight Choices

# %% [markdown]
# ZeroCarbonFly will crawl, calculate and give the grennest, cheapest and shortest flight for you to select.

# %% [markdown]
# ![image%20%281%29.png](attachment:image%20%281%29.png)

# %% [markdown]
# ![Polar-Bear.jpg](attachment:Polar-Bear.jpg)

# %% [markdown]
# # Please Select the Greenest One!

# %% [markdown]
# Since the early 1900s, many glaciers around the world have been rapidly melting. Human activities are at the root of this phenomenon. Specifically, since the industrial revolution, carbon dioxide and other greenhouse gas emissions have raised temperatures, even higher in the poles, and as a result, glaciers are rapidly melting, calving off into the sea and retreating on land.
# Even if we significantly curb emissions in the coming decades, more than a third of the world’s remaining glaciers will melt before the year 2100. When it comes to sea ice, 95% of the oldest and thickest ice in the Arctic is already gone.
#
# Scientists project that if emissions continue to rise unchecked, the Arctic could be ice free in the summer as soon as the year 2040 as ocean and air temperatures continue to rise rapidly. As sea ice and glaciers melt and oceans warm, ocean currents will continue to disrupt weather patterns worldwide. In the Arctic, as sea ice melts, wildlife like walrus are losing their home and polar bears are spending more time on land, causing higher rates of conflict between people and bears.
